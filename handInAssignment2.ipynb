# %%
H = [-0.3,-0.2,-0.1,0,0.1,0.2,0.3]
mUp = [-0.9906,-0.9907,0.9832,0.9863,0.9887,0.9906,0.9886]
mDown = [-0.9898,-0.9920,-0.9904,-0.9864,-0.9844,0.9920,0.9472]
EDown = [-2.2569,-2.1684,-2.0622,-1.9500,-1.8432,-2.1688,-2.2502]

import matplotlib.pyplot as plt

plt.plot(H,mDown)
